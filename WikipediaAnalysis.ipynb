# %% [markdown]
# # Wikipedia Analysis
#
# By Francisco Landa and Teresa Gener
#
# We will start loading the necessary libraries for the task

# %%
import pandas as pd
import re
import numpy as np
pd.set_option('display.max_columns', None)

# %%
from pyspark.sql.types import *
from pyspark.sql.types import ArrayType, StringType,LongType
from pyspark.sql.functions import split, explode, collect_list, count, length

# %%
spark.conf.set("spark.sql.execution.arrow.enabled", "true")

# %% [markdown]
# # Data analysis and preparation
# In this section we prepare the dataset in order to extract the links, quantify them and so on.
# Firstly, we read the data.

# %%
wikipediaDF=spark.read.parquet("dbfs:/databricks-datasets/wikipedia-datasets/data-001/en_wikipedia/articles-only-parquet")

# %% [markdown]
# We select a partial sample of full database, to be able to work in a short time.
# To evaluate this work, please use the entire dataset. We will use a fraction of the data and comment on the results.

# %%
PartialWikipediaDF=wikipediaDF.sample(fraction=0.00001,seed=0).cache()

# %% [markdown]
# We will omit any display but the last one, in order to increase speed beacuse displaying and showing parts heads of the dataframe take a lot of time.

# %%
#PartialWikipediaDF.limit(20).toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>id</th>
#       <th>revisionId</th>
#       <th>revisionTimestamp</th>
#       <th>revisionUsername</th>
#       <th>revisionUsernameId</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Shenzhou 5</td>
#       <td>340927</td>
#       <td>676959742</td>
#       <td>2015-08-20 06:12:27</td>
#       <td>Welsh</td>
#       <td>310131</td>
#       <td>{{Infobox spaceflight | name                  ...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Krylov subspace</td>
#       <td>2542615</td>
#       <td>672927206</td>
#       <td>2015-07-24 20:33:42</td>
#       <td>Cuzkatzimhut</td>
#       <td>2996924</td>
#       <td>In [[linear algebra]], the order-''r'' '''Kryl...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Randleman</td>
#       <td>4254040</td>
#       <td>535859287</td>
#       <td>2013-01-31 13:49:01</td>
#       <td>Xezbeth</td>
#       <td>86247</td>
#       <td>'''Randleman''' may refer to:  * [[Randleman, ...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Loango National Park</td>
#       <td>3509649</td>
#       <td>659005208</td>
#       <td>2015-04-24 15:42:18</td>
#       <td>John of Reading</td>
#       <td>11308236</td>
#       <td>{{Infobox protected area  | name = Loango Nati...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Jan Vang Sørensen</td>
#       <td>4060126</td>
#       <td>638876953</td>
#       <td>2014-12-20 06:36:40</td>
#       <td>Zyxw</td>
#       <td>473593</td>
#       <td>{{Infobox poker player | name = Jan Vang Søren...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Analysing the database, we see the outgoing links are enclosed in "[[]]". We parse the document and detect the links in each wikipedia page.

# %%
def parse_links(document_body):
  data=re.findall(r'\[\[(.+?)\]\]',document_body)
  if (len(data)>0):
    links=[s.lower() for s in data]
  else:
    links=[]
  return links

# %%
parse_links_udf = udf(parse_links,ArrayType(StringType()))

# %% [markdown]
# Then we convert to lowercase the strings to normalize the text.

# %%
tolower_udf= udf(lambda x: x.lower())

# %% [markdown]
# Create a Parsed Wikipedia Dataframe, with the principal columns, and the column text parsed

# %%
ParsedWikipediaDF = PartialWikipediaDF.select(tolower_udf("title").alias("title"),"id",parse_links_udf("text").alias("text_links"))

# %%
#ParsedWikipediaDF.limit(20).toPandas().head()       #to show the dataframe
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>id</th>
#       <th>text_links</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>shenzhou 5</td>
#       <td>340927</td>
#       <td>[shenzhou (spacecraft)|shenzhou, long march 2f...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>krylov subspace</td>
#       <td>2542615</td>
#       <td>[linear algebra, linear subspace, linear span|...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>randleman</td>
#       <td>4254040</td>
#       <td>[randleman, north carolina, randleman high sch...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>loango national park</td>
#       <td>3509649</td>
#       <td>[gabon, national agency for national parks, na...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>jan vang sørensen</td>
#       <td>4060126</td>
#       <td>[2005 world series of poker, seven-card stud, ...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ParsedWikipediaDF.cache
# Out:
# Out[14]: <bound method DataFrame.cache of DataFrame[title: string, id: int, text_links: array<string>]>

# %% [markdown]
# We extract from the full Wikipedia Dataframe the table docuemnt id against title, to convert the outgoing text links to id list, this will be used at the end of the work to match the Page Ranks to ID's and Page Titles

# %%
Titles_ID_DF=wikipediaDF.select(tolower_udf("title").alias("title"),"id")

# %%
#Titles_ID_DF.limit(80).toPandas().head(40)      #uncoment this line to show the ids and title of the pages
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>history of physics</td>
#       <td>13758</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>hydrofoil</td>
#       <td>13761</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>henri chopin</td>
#       <td>13763</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>hassium</td>
#       <td>13764</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>hydrus</td>
#       <td>13768</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>hercules</td>
#       <td>13770</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>history of poland</td>
#       <td>13772</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>hradčany</td>
#       <td>13773</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>houston</td>
#       <td>13774</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>hard disk drive</td>
#       <td>13777</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>hermetic order of the golden dawn</td>
#       <td>13787</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>high jump</td>
#       <td>13791</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>heraclitus</td>
#       <td>13792</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>harrison schmitt</td>
#       <td>13793</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>hilaire rouelle</td>
#       <td>13795</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>halon</td>
#       <td>13798</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>harrisonburg</td>
#       <td>13800</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>hohenstaufen</td>
#       <td>13805</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>history of malaysia</td>
#       <td>13806</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>history of israel</td>
#       <td>13808</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>harvey mudd college</td>
#       <td>13810</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>heaven</td>
#       <td>13811</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>history of libya</td>
#       <td>13812</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>history of afghanistan</td>
#       <td>13813</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>heracles</td>
#       <td>13815</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>henry rollins</td>
#       <td>13820</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>hadron</td>
#       <td>13821</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>heisuke hironaka</td>
#       <td>13822</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>house of habsburg</td>
#       <td>13824</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>hub</td>
#       <td>13826</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>human rights</td>
#       <td>13831</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>"hello, world!" program</td>
#       <td>13834</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>hebrew grammar</td>
#       <td>13845</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>modern hebrew phonology</td>
#       <td>13846</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>house of hohenzollern</td>
#       <td>13849</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>hole</td>
#       <td>13851</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>history of france</td>
#       <td>13854</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>halloween</td>
#       <td>13855</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>hayling island</td>
#       <td>13859</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>hard science fiction</td>
#       <td>13862</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# We will need the titles as static and broadcasted variable, so, we download the Titles_ID SPARK dataframe to Pandas Dataframe (local variable)

# %%
Titles_ID_PDF = Titles_ID_DF.toPandas()

# %%
#display(Titles_ID_PDF)  #uncoment this line to show the titles and ids of the pages
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title</th><th>id</th></tr></thead><tbody><tr><td>history of physics</td><td>13758</td></tr><tr><td>hydrofoil</td><td>13761</td></tr><tr><td>henri chopin</td><td>13763</td></tr><tr><td>hassium</td><td>13764</td></tr><tr><td>hydrus</td><td>13768</td></tr><tr><td>hercules</td><td>13770</td></tr><tr><td>history of poland</td><td>13772</td></tr><tr><td>hradčany</td><td>13773</td></tr><tr><td>houston</td><td>13
# %% [markdown]
# We broadcast the Titles_ID_PDF to all workers

# %%
Titles_ID_BPDF = sc.broadcast(Titles_ID_PDF)

# %% [markdown]
# With the Titles2ID Python function converts a list of titles to list of Documents IDs.
#
# Then, we define the UDF function to be used in Spark

# %%
def Titles2ID (titles):
  links = []
  titles_id_pdf = Titles_ID_BPDF.value # This is a PandasDF
  
  for t in titles:
    row = titles_id_pdf[titles_id_pdf["title"]==t]
    if len(row)>0:
      id = int(row["id"].iloc[-1])
      links.append(id)
  return links

# %%
Titles2ID_udf= udf(Titles2ID,ArrayType(LongType()))

# %% [markdown]
# Now, we create a ForwardLinksTempDF, with the information
# * "id": id of the document
# * "links": list of target documents IDs

# %%
ForwardLinksTempDF=ParsedWikipediaDF.select("id",Titles2ID_udf("text_links").alias("links")).cache()

# %% [markdown]
# Now, we define a UDF function counting, to generate the number of outgoing links information.

# %%
def counting(links):
  return len(links)

# %%
counting_udf=udf(counting,LongType())

# %% [markdown]
# Now, e create the final ForwardLinksDF, with the follow information:
# * "id": documents ids
# * "links": list of outgoing documentID links
# * "outgoing": number of outgoing links for this document
#
# We will need this Dataframe several times, so the better is cache it

# %%
ForwardLinksDF=ForwardLinksTempDF.select("id","links",counting_udf("links").alias("outgoing")).cache()

# %%
ForwardLinksDF.toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>links</th>
#       <th>outgoing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>340927</td>
#       <td>[340917, 869878, 357847, 340934, 26779, 25391,...</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2542615</td>
#       <td>[56357, 173547, 15237, 5975550, 201611, 1134614]</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4254040</td>
#       <td>[128150, 10894321, 38383124]</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3509649</td>
#       <td>[12027, 41618052, 21818, 12027, 5334607, 81818...</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4060126</td>
#       <td>[2210466, 22512, 1439194, 23014, 22512, 33116,...</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>7009414</td>
#       <td>[69080, 285314, 6143251, 63403, 325569, 116886...</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7159975</td>
#       <td>[192573, 167409, 7160158, 192573, 192578]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>6667872</td>
#       <td>[6667940]</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>10919930</td>
#       <td>[528282, 3021828, 414082, 3021828]</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>6572839</td>
#       <td>[2339717, 3097027, 30118, 27283349]</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>9597841</td>
#       <td>[36656, 277226, 3383, 82198, 26997, 1046233, 2...</td>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>6379698</td>
#       <td>[2774053, 2799672, 54080, 54025, 43699347, 384...</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>20895542</td>
#       <td>[38325396, 38325396, 38719157, 2830666, 154489...</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>22371574</td>
#       <td>[8122, 109986, 606746, 8122, 18951490, 8122, 2...</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>22410581</td>
#       <td>[6653, 8354382, 313646, 449552, 92656, 55169, ...</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>39249641</td>
#       <td>[5405, 344775, 173301, 9316, 12080970]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>20482878</td>
#       <td>[122418, 3921, 211165, 768856, 1098087, 11830601]</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>26036541</td>
#       <td>[395935, 5405, 28866408, 294156, 1943900, 3959...</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>42305636</td>
#       <td>[11039790, 19827221, 23366462, 53307, 638719, ...</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>42358235</td>
#       <td>[216932, 6646453, 343524, 23235, 12342320, 822...</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>13511010</td>
#       <td>[124204, 5104139, 6771, 124204, 5104139]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>36893675</td>
#       <td>[15797, 15831, 92633, 3301134, 74200, 35291447...</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>34111854</td>
#       <td>[87972, 48367, 8210131, 216492, 127030, 139376...</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>23736968</td>
#       <td>[8500381, 22318023, 8943760, 108085, 735092, 1...</td>
#       <td>57</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>39014312</td>
#       <td>[155025, 19167, 21433, 12491, 8916248, 2315113...</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>45446916</td>
#       <td>[19127, 17566417]</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>42876958</td>
#       <td>[22308, 9316, 22308, 9316, 1397418, 42877112, ...</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>23255883</td>
#       <td>[63125, 154564, 16086176, 20656228, 23501]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>36575375</td>
#       <td>[11039790, 19827221, 23366462, 53307, 881635, ...</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>47893551</td>
#       <td>[11039790, 19827221, 23366462, 53307, 703270, ...</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>21885285</td>
#       <td>[22936, 1234326, 15130529, 6981602, 182354, 35...</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>13921110</td>
#       <td>[32231, 18184846, 14533, 13677, 554992, 125315...</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>32367472</td>
#       <td>[]</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>29406590</td>
#       <td>[36902294, 22821281, 50821, 5405, 2146364, 508...</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>41834571</td>
#       <td>[41833567, 33367842, 7349754, 448049, 14653]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>46653940</td>
#       <td>[5489, 29032274, 42105780, 40398954]</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>15522609</td>
#       <td>[12108, 460895, 12108, 39696, 100410, 1269180]</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>46508985</td>
#       <td>[19189, 14533, 36496543, 28473060, 43374716, 3...</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>32478441</td>
#       <td>[11039790, 19827221, 23366462, 7044]</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>33441934</td>
#       <td>[12168152, 11160406, 28269, 65834, 4560, 228274]</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>27035875</td>
#       <td>[27338, 4065486, 42374, 27338, 27127426, 40654...</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>45404199</td>
#       <td>[]</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>32281941</td>
#       <td>[309616, 31717, 1377362, 41304982, 55904, 2926...</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>44431524</td>
#       <td>[10079731, 7871141, 1455929, 17882982, 4111187...</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>47670453</td>
#       <td>[21241, 23631621, 22309, 21241, 21241, 372466,...</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Reverse Links Dataframe
# Using the ForwardLinks Dataframe, we will calculate the ReverseLinksDataframe.
# * First, we explode the ForwardLinks Dataframe, to get a big dataframe with:
#   * id: Id of the source document
#   * target: Id of the target document
#   * outgoing: Number of outgoing links for the id document
# * The group by target links, and create a new ReverseLinks Dataframe with the information:
#   * id: Id of the target document
#   * links: list of Ids of all documents who point to this document
#   * outgoing: list of counters of outgoing links for each one of documents Ids inthe links list
#
#
# The ReverseLinksDF is cached and this is the dataframe we will use to calculate the PageRank.
#
# We must also save the terminal nodes for the final output as the future created Reverse Links will not contain them

# %%
TerminalNodes = ForwardLinksDF.filter(ForwardLinksDF["outgoing"] == 0).select("id").toPandas()
TerminalNodes["PR"]=0.85/ForwardLinksDF.count()
#display(TerminalNodes)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>PR</th></tr></thead><tbody><tr><td>32367472</td><td>0.01888888888888889</td></tr><tr><td>45404199</td><td>0.01888888888888889</td></tr></tbody></table></div>

# %%
ReverseTempDF=ForwardLinksDF.select("id",explode("links").alias("target"),"outgoing").distinct()

# %%
#display(ReverseTempDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th
><td>1393385</td><td>List(9597841)</td><td>List(79)</td></tr><tr><td>3434750</td><td>List(340927)</td><td>List(23)</td></tr><tr><td>32706</td><td>List(29406590)</td><td>List(48)</td></tr><tr><td>9056994</td><td>List(9597841)</td><td>List(79)</td></tr><tr><td>25510448</td><td>List(9597841)</td><td>List(79)</td></tr><tr><td>528282</td><td>List(10919930)</td><td>List(4)</td></tr><tr><td>18660332</td><td>List(29406590)</td><td>List(48)</td></tr><tr><td>401880</td><td>List(42358235)</td><td>List(12)</td></tr><tr><td>8452507</td><td>List(20895542)</td><td>List(47)</td></tr><tr><td>1461079</td><td>List(29406590)</td><td>List(48)</td></tr><tr><td>3097027</td><td>List(6572839)</td><td>List(4)</td></tr><tr><td>17306237</td><td>List(29406590)</td><td>List(48)</td></tr><tr><td>313647</td><td>List(22410581)</td><td>List(16)</td></tr><tr><td>3343</td><td>List(32281941)</td><td>List(19)</td></tr><tr><td>31717</td><td>List(32281941)</td><td>List(19)</td></tr><tr><td>10079731</td><td>List(44431524)</td><td>List(6)</td></tr><tr><td>1303670</td><td>List(26036541)</td><td>List(29)</td></tr><tr><td>1664986</td><td>List(20895542)</td><td>List(47)</td></tr><tr><td>28866408</td><td>List(26036541)</td><td>List(29)</td></tr><tr><td>786545</td><td>List(21885285)</td><td>List(9)</td></tr><tr><td>1393764</td><td>List(34111854)</td><td>List(9)</td></tr><tr><td>1852242</td><td>List(9597841)</td><td>List(79)</td></tr><tr><td>551448</td><td>List(6379698)</td><td>List(10)</td></tr><tr><td>63403</td><td>List(7009414)</td><td>List(9)</td></tr><tr><td>41111875</td><td>List(44431524)</td><td>List(6)</td></tr><tr><td>81818</td><td>List(3509649)</td><td>List(13)</td></tr><tr><td>13275</td><td>List(32281941)</td><td>List(19)</td></tr><tr><td>22309268</td><td>List(340927)</td><td>List(23)</td></tr><tr><td>446206</td><td>List(4060126)</td><td>List(12)</td></tr><tr><td>66633</td><td>List(47893551, 42305636)</td><td>List(9, 9)</td></tr><tr><td>3929480</td><td>List(26036541)</td><td>List(29)</td></tr><tr><td>7349754</td><td>List(41834571)</td><td>List(5)</td></tr><tr><td>20092504</td><td>List(260365 ...

# %% [markdown]
# #Initialize the first PageRank Pandas Dataframe
# Using the ReverseLinksDF, we will initialize the PageRank Pandas Dataframe.

# %%
TotalDocs=ReverseLinksDF.count()

# %% [markdown]
# First, we select the documents IDs

# %%
PageRankPDF=ReverseLinksDF.select("id").toPandas()

# %% [markdown]
# Now, we create a new column called PR with the initial PageRank for all documents. We select 0.85/Number of documents.
#
# We also duplicate this column for saving the new calculated PR and the previous one, in order to check faster the variance

# %%
PageRankPDF["PR"] = (0.85/TotalDocs)
PageRankPDF["NewPR"] = PageRankPDF["PR"]

# %%
PageRankPDF
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>PR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>15237</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>63125</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>34063244</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>390975</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>95840</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>441</th>
#       <td>484254</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>442</th>
#       <td>1503080</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>443</th>
#       <td>8943760</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>444</th>
#       <td>1827332</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>445</th>
#       <td>25510447</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# <p>446 rows × 2 columns</p>
# </div>

# %% [markdown]
# We define a Python function which will calculate the next page rank based on the previous PageRank, and the links and counters information in the ReverseLinksDF
# The follow function MUST BE rewrited
# Input parameters:
# * links: list of incoming links (column links in the ReverseDataDF)
# * counters: lis of outgoing links for each document ID in the list links
# * currentPR: Current PageRank Pandas Dataframe, you need this information to calculate the next PR
#
# The exit condition is: more than 20 iterations or the PageRank variation is less than 1e-4:
# $$Vary=\frac{Pr_{n+1}-Pr_{n}}{Pr_n}$$
#
# Vary should be less than 1e-4 for all PageRanks

# %%
# We will receive two pandas columns, PR and NewPR and a t variable to modify the variance if wished
def check_variance(new, old, t):
    return (abs((new-old)/old)<t).head()[0]         # we compute and return a True/False if the entire row of the dataset fullfils the variance condition. If true, the main loop ends


#Function to compute the PR, we will receive a row of the dataframe.
def NewPagerank(links, counters, currentPR)->float:
    d = 0.85                                                            # damping factor
    newPR = 0                                                           # set to 0 the newPR value
    for i in range(len(links)):                                         
        filtered_rows = PageRankPDF[PageRankPDF['id'] == links[i]]      # look or a certain ID's PR 
        if not filtered_rows.empty:                                     # if we have a match
            current_PR = filtered_rows.iloc[0]["PR"]                    # we get the PR
            newPR += (1 - d) + d * (current_PR/ counters[i])            # compute the PR with the given formula and return
        else:
            print(f"No matching row for id {links[i]} found.")          #We inform the user if there is a mismatch
    return float(newPR)
# Out:
# Out[38]: '\ndef NewPagerank2(links, counters, currentPR)->float:\n    d = 0.85  # Damping factor\n    newPR = 0\n    for i in range(len(links)):\n        if counters[i] != 0:\n            newPR += (1 - d) + d * (PageRankPDF[PageRankPDF[\'id\'] == links[i]].iloc[0]["PR"]/ counters[i]) \n        else:\n            #newPR += (1 - d) + d * (PageRankPDF[PageRankPDF[\'id\'] == links[i]].iloc[0]["PR"]/ counters[i])\n    return float(newPR)\n'

# %% [markdown]
# # Main Loop
# We now enter the main loop. 20 iterations or less than a threshold in the variance computation in order to end the loop.
#
# The procedure is simple, iterate the dataframe by rows, call our NewPageRank function with the links, counters and the previous PR of that row, append it to a list we will later add as a column to the dataset.
# Once done, we check the variance condition and end or continue with the algorithm.

# %%
for i in range(20):
  pr = []                                   #create empy list 
  for r in ReverseLinksDF.collect():        #iterate by rows
    pr.append(NewPagerank(r[1],r[2],PageRankPDF[PageRankPDF['id'] == r[0]].iloc[0]["PR"]))    #compute the PR for the row r in the dataframe
  PageRankPDF['NewPR'] = pr                 #add it to the newPR column
  if check_variance(PageRankPDF['NewPR'],PageRankPDF['PR'],0.0001):         #check variance condition if True we finish else we continue
    PageRankPDF['PR'] = PageRankPDF['NewPR']
    print(f"The Page Rank calculation has converged in {i} iterations.")
    break
  else:
    PageRankPDF['PR'] = PageRankPDF['NewPR']                                # we update the columns
# Out:
# No matching row for id 2542615 found.
# No matching row for id 23255883 found.
# No matching row for id 46508985 found.
# No matching row for id 22410581 found.
# No matching row for id 36893675 found.
# No matching row for id 340927 found.
# No matching row for id 39014312 found.
# No matching row for id 29406590 found.
# No matching row for id 22410581 found.
# No matching row for id 32281941 found.
# No matching row for id 9597841 found.
# No matching row for id 2542615 found.
# No matching row for id 340927 found.
# No matching row for id 29406590 found.
# No matching row for id 4060126 found.
# No matching row for id 20895542 found.
# No matching row for id 9597841 found.
# No matching row for id 23736968 found.
# No matching row for id 36893675 found.
# No matching row for id 23736968 found.
# No matching row for id 20482878 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 45446916 found.
# No matching row for id 32281941 found.
# No matching row for id 39014312 found.
# No matching row for id 9597841 found.
# No matching row for id 340927 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 10919930 found.
# No matching row for id 29406590 found.
# No matching row for id 42358235 found.
# No matching row for id 20895542 found.
# No matching row for id 29406590 found.
# No matching row for id 6572839 found.
# No matching row for id 29406590 found.
# No matching row for id 22410581 found.
# No matching row for id 32281941 found.
# No matching row for id 32281941 found.
# No matching row for id 44431524 found.
# No matching row for id 26036541 found.
# No matching row for id 20895542 found.
# No matching row for id 26036541 found.
# No matching row for id 21885285 found.
# No matching row for id 34111854 found.
# No matching row for id 9597841 found.
# No matching row for id 6379698 found.
# No matching row for id 7009414 found.
# No matching row for id 44431524 found.
# No matching row for id 3509649 found.
# No matching row for id 32281941 found.
# No matching row for id 340927 found.
# No matching row for id 4060126 found.
# No matching row for id 47893551 found.
# No matching row for id 42305636 found.
# No matching row for id 26036541 found.
# No matching row for id 41834571 found.
# No matching row for id 26036541 found.
# No matching row for id 26036541 found.
# No matching row for id 36893675 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 20895542 found.
# No matching row for id 26036541 found.
# No matching row for id 29406590 found.
# No matching row for id 39249641 found.
# No matching row for id 9597841 found.
# No matching row for id 2542615 found.
# No matching row for id 6379698 found.
# No matching row for id 23736968 found.
# No matching row for id 23255883 found.
# No matching row for id 23736968 found.
# No matching row for id 340927 found.
# No matching row for id 13921110 found.
# No matching row for id 13921110 found.
# No matching row for id 23736968 found.
# No matching row for id 26036541 found.
# No matching row for id 20895542 found.
# No matching row for id 9597841 found.
# No matching row for id 20895542 found.
# No matching row for id 39014312 found.
# No matching row for id 23736968 found.
# No matching row for id 13921110 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 340927 found.
# No matching row for id 9597841 found.
# No matching row for id 36893675 found.
# No matching row for id 20482878 found.
# No matching row for id 34111854 found.
# No matching row for id 20895542 found.
# No matching row for id 36893675 found.
# No matching row for id 20482878 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 29406590 found.
# No matching row for id 29406590 found.
# No matching row for id 6379698 found.
# No matching row for id 20895542 found.
# No matching row for id 20895542 found.
# No matching row for id 9597841 found.
# No matching row for id 47670453 found.
# No matching row for id 10919930 found.
# No matching row for id 44431524 found.
# No matching row for id 23736968 found.
# No matching row for id 32281941 found.
# No matching row for id 36893675 found.
# No matching row for id 9597841 found.
# No matching row for id 42358235 found.
# No matching row for id 44431524 found.
# No matching row for id 34111854 found.
# No matching row for id 3509649 found.
# No matching row for id 15522609 found.
# No matching row for id 10919930 found.
# No matching row for id 45446916 found.
# No matching row for id 29406590 found.
# No matching row for id 32281941 found.
# No matching row for id 34111854 found.
# No matching row for id 36893675 found.
# No matching row for id 4060126 found.
# No matching row for id 20895542 found.
# No matching row for id 20895542 found.
# No matching row for id 340927 found.
# No matching row for id 20895542 found.
# No matching row for id 41834571 found.
# No matching row for id 9597841 found.
# No matching row for id 42876958 found.
# No matching row for id 39249641 found.
# No matching row for id 47893551 found.
# No matching row for id 32478441 found.
# No matching row for id 42305636 found.
# No matching row for id 36575375 found.
# No matching row for id 9597841 found.
# No matching row for id 39014312 found.
# No matching row for id 22371574 found.
# No matching row for id 22371574 found.
# No matching row for id 9597841 found.
# No matching row for id 3509649 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 6379698 found.
# No matching row for id 26036541 found.
# No matching row for id 9597841 found.
# No matching row for id 23736968 found.
# No matching row for id 46653940 found.
# No matching row for id 20895542 found.
# No matching row for id 7009414 found.
# No matching row for id 42358235 found.
# No matching row for id 20895542 found.
# No matching row for id 20895542 found.
# No matching row for id 20895542 found.
# No matching row for id 23255883 found.
# No matching row for id 2542615 found.
# No matching row for id 47670453 found.
# No matching row for id 26036541 found.
# No matching row for id 33441934 found.
# No matching row for id 32281941 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 29406590 found.
# No matching row for id 22371574 found.
# No matching row for id 22410581 found.
# No matching row for id 20482878 found.
# No matching row for id 44431524 found.
# No matching row for id 13511010 found.
# No matching row for id 22371574 found.
# No matching row for id 29406590 found.
# No matching row for id 39014312 found.
# No matching row for id 29406590 found.
# No matching row for id 15522609 found.
# No matching row for id 22410581 found.
# No matching row for id 340927 found.
# No matching row for id 34111854 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 6379698 found.
# No matching row for id 46508985 found.
# No matching row for id 3509649 found.
# No matching row for id 20895542 found.
# No matching row for id 39014312 found.
# No matching row for id 9597841 found.
# No matching row for id 42876958 found.
# No matching row for id 42876958 found.
# No matching row for id 6572839 found.
# No matching row for id 15522609 found.
# No matching row for id 26036541 found.
# No matching row for id 9597841 found.
# No matching row for id 36575375 found.
# No matching row for id 9597841 found.
# No matching row for id 340927 found.
# No matching row for id 340927 found.
# No matching row for id 9597841 found.
# No matching row for id 26036541 found.
# No matching row for id 44431524 found.
# No matching row for id 32281941 found.
# No matching row for id 13921110 found.
# No matching row for id 26036541 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# No matching row for id 46653940 found.
# No matching row for id 29406590 found.
# No matching row for id 6379698 found.
# No matching row for id 22371574 found.
# No matching row for id 20482878 found.
# No matching row for id 47893551 found.
# No matching row for id 15522609 found.
# No matching row for id 7159975 found.
# No matching row for id 29406590 found.
# No matching row for id 23736968 found.
# No matching row for id 42876958 found.
# No matching row for id 22410581 found.
# No matching row for id 2542615 found.
# No matching row for id 3509649 found.
# No matching row for id 26036541 found.
# No matching row for id 26036541 found.
# No matching row for id 39014312 found.
# No matching row for id 42358235 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 26036541 found.
# No matching row for id 36575375 found.
# No matching row for id 20895542 found.
# No matching row for id 23255883 found.
# No matching row for id 32281941 found.
# No matching row for id 32281941 found.
# No matching row for id 32281941 found.
# No matching row for id 42358235 found.
# No matching row for id 26036541 found.
# No matching row for id 42876958 found.
# No matching row for id 9597841 found.
# No matching row for id 7009414 found.
# No matching row for id 21885285 found.
# No matching row for id 26036541 found.
# No matching row for id 340927 found.
# No matching row for id 34111854 found.
# No matching row for id 9597841 found.
# No matching row for id 46508985 found.
# No matching row for id 23736968 found.
# No matching row for id 42305636 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 47893551 found.
# No matching row for id 26036541 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# No matching row for id 29406590 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 9597841 found.
# No matching row for id 6379698 found.
# No matching row for id 7159975 found.
# No matching row for id 340927 found.
# No matching row for id 22371574 found.
# No matching row for id 39014312 found.
# No matching row for id 47670453 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# No matching row for id 33441934 found.
# No matching row for id 41834571 found.
# No matching row for id 6379698 found.
# No matching row for id 9597841 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# No matching row for id 20895542 found.
# No matching row for id 42876958 found.
# No matching row for id 34111854 found.
# No matching row for id 27035875 found.
# No matching row for id 20895542 found.
# No matching row for id 32281941 found.
# No matching row for id 46508985 found.
# No matching row for id 13921110 found.
# No matching row for id 32281941 found.
# No matching row for id 39249641 found.
# No matching row for id 9597841 found.
# No matching row for id 22371574 found.
# No matching row for id 23736968 found.
# No matching row for id 21885285 found.
# No matching row for id 29406590 found.
# No matching row for id 47670453 found.
# No matching row for id 7009414 found.
# No matching row for id 39249641 found.
# No matching row for id 39014312 found.
# No matching row for id 21885285 found.
# No matching row for id 42876958 found.
# No matching row for id 9597841 found.
# No matching row for id 42305636 found.
# No matching row for id 32478441 found.
# No matching row for id 47893551 found.
# No matching row for id 36575375 found.
# No matching row for id 3509649 found.
# No matching row for id 4060126 found.
# No matching row for id 42358235 found.
# No matching row for id 42305636 found.
# No matching row for id 33441934 found.
# No matching row for id 9597841 found.
# No matching row for id 3509649 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 7009414 found.
# No matching row for id 46508985 found.
# No matching row for id 29406590 found.
# No matching row for id 340927 found.
# No matching row for id 9597841 found.
# No matching row for id 42876958 found.
# No matching row for id 42358235 found.
# No matching row for id 34111854 found.
# No matching row for id 39014312 found.
# No matching row for id 340927 found.
# No matching row for id 23736968 found.
# No matching row for id 9597841 found.
# No matching row for id 39249641 found.
# No matching row for id 21885285 found.
# No matching row for id 26036541 found.
# No matching row for id 27035875 found.
# No matching row for id 27035875 found.
# No matching row for id 36893675 found.
# No matching row for id 7159975 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 29406590 found.
# No matching row for id 3509649 found.
# No matching row for id 22410581 found.
# No matching row for id 4060126 found.
# No matching row for id 9597841 found.
# No matching row for id 29406590 found.
# No matching row for id 4254040 found.
# No matching row for id 27035875 found.
# No matching row for id 36893675 found.
# No matching row for id 13511010 found.
# No matching row for id 6667872 found.
# No matching row for id 42305636 found.
# No matching row for id 32478441 found.
# No matching row for id 340927 found.
# No matching row for id 23736968 found.
# No matching row for id 47670453 found.
# No matching row for id 23736968 found.
# No matching row for id 36893675 found.
# No matching row for id 9597841 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 7009414 found.
# No matching row for id 9597841 found.
# No matching row for id 36893675 found.
# No matching row for id 46653940 found.
# No matching row for id 3509649 found.
# No matching row for id 42358235 found.
# No matching row for id 4060126 found.
# No matching row for id 39014312 found.
# No matching row for id 26036541 found.
# No matching row for id 32281941 found.
# No matching row for id 20895542 found.
# No matching row for id 36893675 found.
# No matching row for id 22410581 found.
# No matching row for id 7009414 found.
# No matching row for id 9597841 found.
# No matching row for id 22410581 found.
# No matching row for id 36893675 found.
# No matching row for id 20895542 found.
# No matching row for id 32281941 found.
# No matching row for id 47893551 found.
# No matching row for id 36575375 found.
# No matching row for id 42305636 found.
# No matching row for id 20895542 found.
# No matching row for id 3509649 found.
# No matching row for id 13511010 found.
# No matching row for id 7159975 found.
# No matching row for id 4060126 found.
# No matching row for id 41834571 found.
# No matching row for id 340927 found.
# No matching row for id 23736968 found.
# No matching row for id 3509649 found.
# No matching row for id 4254040 found.
# No matching row for id 27035875 found.
# No matching row for id 29406590 found.
# No matching row for id 4254040 found.
# No matching row for id 20895542 found.
# No matching row for id 36575375 found.
# No matching row for id 46508985 found.
# No matching row for id 29406590 found.
# No matching row for id 21885285 found.
# No matching row for id 13921110 found.
# No matching row for id 21885285 found.
# No matching row for id 22410581 found.
# No matching row for id 22371574 found.
# No matching row for id 46508985 found.
# No matching row for id 20895542 found.
# No matching row for id 22371574 found.
# No matching row for id 27035875 found.
# No matching row for id 41834571 found.
# No matching row for id 15522609 found.
# No matching row for id 9597841 found.
# No matching row for id 21885285 found.
# No matching row for id 20482878 found.
# No matching row for id 29406590 found.
# No matching row for id 2542615 found.
# No matching row for id 33441934 found.
# No matching row for id 4060126 found.
# No matching row for id 9597841 found.
# No matching row for id 22371574 found.
# No matching row for id 21885285 found.
# No matching row for id 6379698 found.
# No matching row for id 9597841 found.
# No matching row for id 32281941 found.
# No matching row for id 23736968 found.
# No matching row for id 6572839 found.
# No matching row for id 46653940 found.
# No matching row for id 29406590 found.
# No matching row for id 22410581 found.
# No matching row for id 23736968 found.
# No matching row for id 20895542 found.
# No matching row for id 6572839 found.
# No matching row for id 23736968 found.
# No matching row for id 32281941 found.
# No matching row for id 20895542 found.
# No matching row for id 23736968 found.
# No matching row for id 47893551 found.
# No matching row for id 42305636 found.
# No matching row for id 36575375 found.
# No matching row for id 32478441 found.
# No matching row for id 340927 found.
# No matching row for id 20895542 found.
# No matching row for id 36893675 found.
# No matching row for id 33441934 found.
# No matching row for id 22410581 found.
# No matching row for id 22410581 found.
# No matching row for id 36893675 found.
# No matching row for id 3509649 found.
# No matching row for id 22410581 found.
# No matching row for id 340927 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 32281941 found.
# No matching row for id 23736968 found.
# No matching row for id 4060126 found.
# No matching row for id 23736968 found.
# No matching row for id 23255883 found.
# No matching row for id 26036541 found.
# No matching row for id 27035875 found.
# No matching row for id 22371574 found.
# No matching row for id 36893675 found.
# No matching row for id 4060126 found.
# No matching row for id 9597841 found.
# No matching row for id 22410581 found.
# No matching row for id 13921110 found.
# No matching row for id 42358235 found.
# No matching row for id 42358235 found.
# No matching row for id 4060126 found.
# No matching row for id 9597841 found.
# No matching row for id 47893551 found.
# No matching row for id 42876958 found.
# No matching row for id 20895542 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 36893675 found.
# No matching row for id 7009414 found.
# No matching row for id 39014312 found.
# No matching row for id 46508985 found.
# No matching row for id 33441934 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 23736968 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# No matching row for id 2542615 found.
# No matching row for id 23255883 found.
# No matching row for id 46508985 found.
# No matching row for id 22410581 found.
# No matching row for id 36893675 found.
# No matching row for id 340927 found.
# No matching row for id 39014312 found.
# No matching row for id 29406590 found.
# No matching row for id 22410581 found.
# No matching row for id 32281941 found.
# No matching row for id 9597841 found.
# No matching row for id 2542615 found.
# No matching row for id 340927 found.
# No matching row for id 29406590 found.
# No matching row for id 4060126 found.
# No matching row for id 20895542 found.
# No matching row for id 9597841 found.
# No matching row for id 23736968 found.
# No matching row for id 36893675 found.
# No matching row for id 23736968 found.
# No matching row for id 20482878 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 45446916 found.
# No matching row for id 32281941 found.
# No matching row for id 39014312 found.
# No matching row for id 9597841 found.
# No matching row for id 340927 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 10919930 found.
# No matching row for id 29406590 found.
# No matching row for id 42358235 found.
# No matching row for id 20895542 found.
# No matching row for id 29406590 found.
# No matching row for id 6572839 found.
# No matching row for id 29406590 found.
# No matching row for id 22410581 found.
# No matching row for id 32281941 found.
# No matching row for id 32281941 found.
# No matching row for id 44431524 found.
# No matching row for id 26036541 found.
# No matching row for id 20895542 found.
# No matching row for id 26036541 found.
# No matching row for id 21885285 found.
# No matching row for id 34111854 found.
# No matching row for id 9597841 found.
# No matching row for id 6379698 found.
# No matching row for id 7009414 found.
# No matching row for id 44431524 found.
# No matching row for id 3509649 found.
# No matching row for id 32281941 found.
# No matching row for id 340927 found.
# No matching row for id 4060126 found.
# No matching row for id 47893551 found.
# No matching row for id 42305636 found.
# No matching row for id 26036541 found.
# No matching row for id 41834571 found.
# No matching row for id 26036541 found.
# No matching row for id 26036541 found.
# No matching row for id 36893675 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 20895542 found.
# No matching row for id 26036541 found.
# No matching row for id 29406590 found.
# No matching row for id 39249641 found.
# No matching row for id 9597841 found.
# No matching row for id 2542615 found.
# No matching row for id 6379698 found.
# No matching row for id 23736968 found.
# No matching row for id 23255883 found.
# No matching row for id 23736968 found.
# No matching row for id 340927 found.
# No matching row for id 13921110 found.
# No matching row for id 13921110 found.
# No matching row for id 23736968 found.
# No matching row for id 26036541 found.
# No matching row for id 20895542 found.
# No matching row for id 9597841 found.
# No matching row for id 20895542 found.
# No matching row for id 39014312 found.
# No matching row for id 23736968 found.
# No matching row for id 13921110 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 340927 found.
# No matching row for id 9597841 found.
# No matching row for id 36893675 found.
# No matching row for id 20482878 found.
# No matching row for id 34111854 found.
# No matching row for id 20895542 found.
# No matching row for id 36893675 found.
# No matching row for id 20482878 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 29406590 found.
# No matching row for id 29406590 found.
# No matching row for id 6379698 found.
# No matching row for id 20895542 found.
# No matching row for id 20895542 found.
# No matching row for id 9597841 found.
# No matching row for id 47670453 found.
# No matching row for id 10919930 found.
# No matching row for id 44431524 found.
# No matching row for id 23736968 found.
# No matching row for id 32281941 found.
# No matching row for id 36893675 found.
# No matching row for id 9597841 found.
# No matching row for id 42358235 found.
# No matching row for id 44431524 found.
# No matching row for id 34111854 found.
# No matching row for id 3509649 found.
# No matching row for id 15522609 found.
# No matching row for id 10919930 found.
# No matching row for id 45446916 found.
# No matching row for id 29406590 found.
# No matching row for id 32281941 found.
# No matching row for id 34111854 found.
# No matching row for id 36893675 found.
# No matching row for id 4060126 found.
# No matching row for id 20895542 found.
# No matching row for id 20895542 found.
# No matching row for id 340927 found.
# No matching row for id 20895542 found.
# No matching row for id 41834571 found.
# No matching row for id 9597841 found.
# No matching row for id 42876958 found.
# No matching row for id 39249641 found.
# No matching row for id 47893551 found.
# No matching row for id 32478441 found.
# No matching row for id 42305636 found.
# No matching row for id 36575375 found.
# No matching row for id 9597841 found.
# No matching row for id 39014312 found.
# No matching row for id 22371574 found.
# No matching row for id 22371574 found.
# No matching row for id 9597841 found.
# No matching row for id 3509649 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 6379698 found.
# No matching row for id 26036541 found.
# No matching row for id 9597841 found.
# No matching row for id 23736968 found.
# No matching row for id 46653940 found.
# No matching row for id 20895542 found.
# No matching row for id 7009414 found.
# No matching row for id 42358235 found.
# No matching row for id 20895542 found.
# No matching row for id 20895542 found.
# No matching row for id 20895542 found.
# No matching row for id 23255883 found.
# No matching row for id 2542615 found.
# No matching row for id 47670453 found.
# No matching row for id 26036541 found.
# No matching row for id 33441934 found.
# No matching row for id 32281941 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 29406590 found.
# No matching row for id 22371574 found.
# No matching row for id 22410581 found.
# No matching row for id 20482878 found.
# No matching row for id 44431524 found.
# No matching row for id 13511010 found.
# No matching row for id 22371574 found.
# No matching row for id 29406590 found.
# No matching row for id 39014312 found.
# No matching row for id 29406590 found.
# No matching row for id 15522609 found.
# No matching row for id 22410581 found.
# No matching row for id 340927 found.
# No matching row for id 34111854 found.
# No match
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# 05636 found.
# No matching row for id 32478441 found.
# No matching row for id 47893551 found.
# No matching row for id 36575375 found.
# No matching row for id 3509649 found.
# No matching row for id 4060126 found.
# No matching row for id 42358235 found.
# No matching row for id 42305636 found.
# No matching row for id 33441934 found.
# No matching row for id 9597841 found.
# No matching row for id 3509649 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 7009414 found.
# No matching row for id 46508985 found.
# No matching row for id 29406590 found.
# No matching row for id 340927 found.
# No matching row for id 9597841 found.
# No matching row for id 42876958 found.
# No matching row for id 42358235 found.
# No matching row for id 34111854 found.
# No matching row for id 39014312 found.
# No matching row for id 340927 found.
# No matching row for id 23736968 found.
# No matching row for id 9597841 found.
# No matching row for id 39249641 found.
# No matching row for id 21885285 found.
# No matching row for id 26036541 found.
# No matching row for id 27035875 found.
# No matching row for id 27035875 found.
# No matching row for id 36893675 found.
# No matching row for id 7159975 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 29406590 found.
# No matching row for id 3509649 found.
# No matching row for id 22410581 found.
# No matching row for id 4060126 found.
# No matching row for id 9597841 found.
# No matching row for id 29406590 found.
# No matching row for id 4254040 found.
# No matching row for id 27035875 found.
# No matching row for id 36893675 found.
# No matching row for id 13511010 found.
# No matching row for id 6667872 found.
# No matching row for id 42305636 found.
# No matching row for id 32478441 found.
# No matching row for id 340927 found.
# No matching row for id 23736968 found.
# No matching row for id 47670453 found.
# No matching row for id 23736968 found.
# No matching row for id 36893675 found.
# No matching row for id 9597841 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 7009414 found.
# No matching row for id 9597841 found.
# No matching row for id 36893675 found.
# No matching row for id 46653940 found.
# No matching row for id 3509649 found.
# No matching row for id 42358235 found.
# No matching row for id 4060126 found.
# No matching row for id 39014312 found.
# No matching row for id 26036541 found.
# No matching row for id 32281941 found.
# No matching row for id 20895542 found.
# No matching row for id 36893675 found.
# No matching row for id 22410581 found.
# No matching row for id 7009414 found.
# No matching row for id 9597841 found.
# No matching row for id 22410581 found.
# No matching row for id 36893675 found.
# No matching row for id 20895542 found.
# No matching row for id 32281941 found.
# No matching row for id 47893551 found.
# No matching row for id 36575375 found.
# No matching row for id 42305636 found.
# No matching row for id 20895542 found.
# No matching row for id 3509649 found.
# No matching row for id 13511010 found.
# No matching row for id 7159975 found.
# No matching row for id 4060126 found.
# No matching row for id 41834571 found.
# No matching row for id 340927 found.
# No matching row for id 23736968 found.
# No matching row for id 3509649 found.
# No matching row for id 4254040 found.
# No matching row for id 27035875 found.
# No matching row for id 29406590 found.
# No matching row for id 4254040 found.
# No matching row for id 20895542 found.
# No matching row for id 36575375 found.
# No matching row for id 46508985 found.
# No matching row for id 29406590 found.
# No matching row for id 21885285 found.
# No matching row for id 13921110 found.
# No matching row for id 21885285 found.
# No matching row for id 22410581 found.
# No matching row for id 22371574 found.
# No matching row for id 46508985 found.
# No matching row for id 20895542 found.
# No matching row for id 22371574 found.
# No matching row for id 27035875 found.
# No matching row for id 41834571 found.
# No matching row for id 15522609 found.
# No matching row for id 9597841 found.
# No matching row for id 21885285 found.
# No matching row for id 20482878 found.
# No matching row for id 29406590 found.
# No matching row for id 2542615 found.
# No matching row for id 33441934 found.
# No matching row for id 4060126 found.
# No matching row for id 9597841 found.
# No matching row for id 22371574 found.
# No matching row for id 21885285 found.
# No matching row for id 6379698 found.
# No matching row for id 9597841 found.
# No matching row for id 32281941 found.
# No matching row for id 23736968 found.
# No matching row for id 6572839 found.
# No matching row for id 46653940 found.
# No matching row for id 29406590 found.
# No matching row for id 22410581 found.
# No matching row for id 23736968 found.
# No matching row for id 20895542 found.
# No matching row for id 6572839 found.
# No matching row for id 23736968 found.
# No matching row for id 32281941 found.
# No matching row for id 20895542 found.
# No matching row for id 23736968 found.
# No matching row for id 47893551 found.
# No matching row for id 42305636 found.
# No matching row for id 36575375 found.
# No matching row for id 32478441 found.
# No matching row for id 340927 found.
# No matching row for id 20895542 found.
# No matching row for id 36893675 found.
# No matching row for id 33441934 found.
# No matching row for id 22410581 found.
# No matching row for id 22410581 found.
# No matching row for id 36893675 found.
# No matching row for id 3509649 found.
# No matching row for id 22410581 found.
# No matching row for id 340927 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 32281941 found.
# No matching row for id 23736968 found.
# No matching row for id 4060126 found.
# No matching row for id 23736968 found.
# No matching row for id 23255883 found.
# No matching row for id 26036541 found.
# No matching row for id 27035875 found.
# No matching row for id 22371574 found.
# No matching row for id 36893675 found.
# No matching row for id 4060126 found.
# No matching row for id 9597841 found.
# No matching row for id 22410581 found.
# No matching row for id 13921110 found.
# No matching row for id 42358235 found.
# No matching row for id 42358235 found.
# No matching row for id 4060126 found.
# No matching row for id 9597841 found.
# No matching row for id 47893551 found.
# No matching row for id 42876958 found.
# No matching row for id 20895542 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 36893675 found.
# No matching row for id 7009414 found.
# No matching row for id 39014312 found.
# No matching row for id 46508985 found.
# No matching row for id 33441934 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 23736968 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# No matching row for id 2542615 found.
# No matching row for id 23255883 found.
# No matching row for id 46508985 found.
# No matching row for id 22410581 found.
# No matching row for id 36893675 found.
# No matching row for id 340927 found.
# No matching row for id 39014312 found.
# No matching row for id 29406590 found.
# No matching row for id 22410581 found.
# No matching row for id 32281941 found.
# No matching row for id 9597841 found.
# No matching row for id 2542615 found.
# No matching row for id 340927 found.
# No matching row for id 29406590 found.
# No matching row for id 4060126 found.
# No matching row for id 20895542 found.
# No matching row for id 9597841 found.
# No matching row for id 23736968 found.
# No matching row for id 36893675 found.
# No matching row for id 23736968 found.
# No matching row for id 20482878 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 45446916 found.
# No matching row for id 32281941 found.
# No matching row for id 39014312 found.
# No matching row for id 9597841 found.
# No matching row for id 340927 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 10919930 found.
# No matching row for id 29406590 found.
# No matching row for id 42358235 found.
# No matching row for id 20895542 found.
# No matching row for id 29406590 found.
# No matching row for id 6572839 found.
# No matching row for id 29406590 found.
# No matching row for id 22410581 found.
# No matching row for id 32281941 found.
# No matching row for id 32281941 found.
# No matching row for id 44431524 found.
# No matching row for id 26036541 found.
# No matching row for id 20895542 found.
# No matching row for id 26036541 found.
# No matching row for id 21885285 found.
# No matching row for id 34111854 found.
# No matching row for id 9597841 found.
# No matching row for id 6379698 found.
# No matching row for id 7009414 found.
# No matching row for id 44431524 found.
# No matching row for id 3509649 found.
# No matching row for id 32281941 found.
# No matching row for id 340927 found.
# No matching row for id 4060126 found.
# No matching row for id 47893551 found.
# No matching row for id 42305636 found.
# No matching row for id 26036541 found.
# No matching row for id 41834571 found.
# No matching row for id 26036541 found.
# No matching row for id 26036541 found.
# No matching row for id 36893675 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 20895542 found.
# No matching row for id 26036541 found.
# No matching row for id 29406590 found.
# No matching row for id 39249641 found.
# No matching row for id 9597841 found.
# No matching row for id 2542615 found.
# No matching row for id 6379698 found.
# No matching row for id 23736968 found.
# No matching row for id 23255883 found.
# No matching row for id 23736968 found.
# No matching row for id 340927 found.
# No matching row for id 13921110 found.
# No matching row for id 13921110 found.
# No matching row for id 23736968 found.
# No matching row for id 26036541 found.
# No matching row for id 20895542 found.
# No matching row for id 9597841 found.
# No matching row for id 20895542 found.
# No matching row for id 39014312 found.
# No matching row for id 23736968 found.
# No matching row for id 13921110 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 340927 found.
# No matching row for id 9597841 found.
# No matching row for id 36893675 found.
# No matching row for id 20482878 found.
# No matching row for id 34111854 found.
# No matching row for id 20895542 found.
# No matching row for id 36893675 found.
# No matching row for id 20482878 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 29406590 found.
# No matching row for id 29406590 found.
# No matching row for id 6379698 found.
# No matching row for id 20895542 found.
# No matching row for id 20895542 found.
# No matching row for id 9597841 found.
# No matching row for id 47670453 found.
# No matching row for id 10919930 found.
# No matching row for id 44431524 found.
# No matching row for id 23736968 found.
# No matching row for id 32281941 found.
# No matching row for id 36893675 found.
# No matching row for id 9597841 found.
# No matching row for id 42358235 found.
# No matching row for id 44431524 found.
# No matching row for id 34111854 found.
# No matching row for id 3509649 found.
# No matching row for id 15522609 found.
# No matching row for id 10919930 found.
# No matching row for id 45446916 found.
# No matching row for id 29406590 found.
# No matching row for id 32281941 found.
# No matching row for id 34111854 found.
# No matching row for id 36893675 found.
# No matching row for id 4060126 found.
# No matching row for id 20895542 found.
# No matching row for id 20895542 found.
# No matching row for id 340927 found.
# No matching row for id 20895542 found.
# No matching row for id 41834571 found.
# No matching row for id 9597841 found.
# No matching row for id 42876958 found.
# No matching row for id 39249641 found.
# No matching row for id 47893551 found.
# No matching row for id 32478441 found.
# No matching row for id 42305636 found.
# No matching row for id 36575375 found.
# No matching row for id 9597841 found.
# No matching row for id 39014312 found.
# No matching row for id 22371574 found.
# No matching row for id 22371574 found.
# No matching row for id 9597841 found.
# No matching row for id 3509649 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 6379698 found.
# No matching row for id 26036541 found.
# No matching row for id 9597841 found.
# No matching row for id 23736968 found.
# No matching row for id 46653940 found.
# No matching row for id 20895542 found.
# No matching row for id 7009414 found.
# No matching row for id 42358235 found.
# No matching row for id 20895542 found.
# No matching row for id 20895542 found.
# No matching row for id 20895542 found.
# No matching row for id 23255883 found.
# No matching row for id 2542615 found.
# No matching row for id 47670453 found.
# No matching row for id 26036541 found.
# No matching row for id 33441934 found.
# No matching row for id 32281941 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 29406590 found.
# No matching row for id 22371574 found.
# No matching row for id 22410581 found.
# No matching row for id 20482878 found.
# No matching row for id 44431524 found.
# No matching row for id 13511010 found.
# No matching row for id 22371574 found.
# No matching row for id 29406590 found.
# No matching row for id 39014312 found.
# No matching row for id 29406590 found.
# No matching row for id 15522609 found.
# No matching row for id 22410581 found.
# No matching row for id 340927 found.
# No matching row for id 34111854 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 6379698 found.
# No matching row for id 46508985 found.
# No matching row for id 3509649 found.
# No matching row for id 20895542 found.
# No matching row for id 39014312 found.
# No matching row for id 9597841 found.
# No matching row for id 42876958 found.
# No matching row for id 42876958 found.
# No matching row for id 6572839 found.
# No matching row for id 15522609 found.
# No matching row for id 26036541 found.
# No matching row for id 9597841 found.
# No matching row for id 36575375 found.
# No matching row for id 9597841 found.
# No matching row for id 340927 found.
# No matching row for id 340927 found.
# No matching row for id 9597841 found.
# No matching row for id 26036541 found.
# No matching row for id 44431524 found.
# No matching row for id 32281941 found.
# No matching row for id 13921110 found.
# No matching row for id 26036541 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# No matching row for id 46653940 found.
# No matching row for id 29406590 found.
# No matching row for id 6379698 found.
# No matching row for id 22371574 found.
# No matching row for id 20482878 found.
# No matching row for id 47893551 found.
# No matching row for id 15522609 found.
# No matching row for id 7159975 found.
# No matching row for id 29406590 found.
# No matching row for id 23736968 found.
# No matching row for id 42876958 found.
# No matching row for id 22410581 found.
# No matching row for id 2542615 found.
# No matching row for id 3509649 found.
# No matching row for id 26036541 found.
# No matching row for id 26036541 found.
# No matching row for id 39014312 found.
# No matching row for id 42358235 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 26036541 found.
# No matching row for id 36575375 found.
# No matching row for id 20895542 found.
# No matching row for id 23255883 found.
# No matching row for id 32281941 found.
# No matching row for id 32281941 found.
# No matching row for id 32281941 found.
# No matching row for id 42358235 found.
# No matching row for id 26036541 found.
# No matching row for id 42876958 found.
# No matching row for id 9597841 found.
# No matching row for id 7009414 found.
# No matching row for id 21885285 found.
# No matching row for id 26036541 found.
# No matching row for id 340927 found.
# No matching row for id 34111854 found.
# No matching row for id 9597841 found.
# No matching row for id 46508985 found.
# No matching row for id 23736968 found.
# No matching row for id 42305636 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 47893551 found.
# No matching row for id 26036541 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# No matching row for id 29406590 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 9597841 found.
# No matching row for id 6379698 found.
# No matching row for id 7159975 found.
# No matching row for id 340927 found.
# No matching row for id 22371574 found.
# No matching row for id 39014312 found.
# No matching row for id 47670453 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# No matching row for id 33441934 found.
# No matching row for id 41834571 found.
# No matching row for id 6379698 found.
# No matching row for id 9597841 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# No matching row for id 20895542 found.
# No matching row for id 42876958 found.
# No matching row for id 34111854 found.
# No matching row for id 27035875 found.
# No matching row for id 20895542 found.
# No matching row for id 32281941 found.
# No matching row for id 46508985 found.
# No matching row for id 13921110 found.
# No matching row for id 32281941 found.
# No matching row for id 39249641 found.
# No matching row for id 9597841 found.
# No matching row for id 22371574 found.
# No matching row for id 23736968 found.
# No matching row for id 21885285 found.
# No matching row for id 29406590 found.
# No matching row for id 47670453 found.
# No matching row for id 7009414 found.
# No matching row for id 39249641 found.
# No matching row for id 39014312 found.
# No matching row for id 21885285 found.
# No matching row for id 42876958 found.
# No matching row for id 9597841 found.
# No matching row for id 42305636 found.
# No matching row for id 32478441 found.
# No matching row for id 47893551 found.
# No matching row for id 36575375 found.
# No matching row for id 3509649 found.
# No matching row for id 4060126 found.
# No matching row for id 42358235 found.
# No matching row for id 42305636 found.
# No matching row for id 33441934 found.
# No matching row for id 9597841 found.
# No matching row for id 3509649 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 7009414 found.
# No matching row for id 46508985 found.
# No matching row for id 29406590 found.
# No matching row for id 340927 found.
# No matching row for id 9597841 found.
# No matching row for id 42876958 found.
# No matching row for id 42358235 found.
# No matching row for id 34111854 found.
# No matching row for id 39014312 found.
# No matching row for id 340927 found.
# No matching row for id 23736968 found.
# No matching row for id 9597841 found.
# No matching row for id 39249641 found.
# No matching row for id 21885285 found.
# No matching row for id 26036541 found.
# No matching row for id 27035875 found.
# No matching row for id 27035875 found.
# No matching row for id 36893675 found.
# No matching row for id 7159975 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 29406590 found.
# No matching row for id 3509649 found.
# No matching row for id 22410581 found.
# No matching row for id 4060126 found.
# No matching row for id 9597841 found.
# No matching row for id 29406590 found.
# No matching row for id 4254040 found.
# No matching row for id 27035875 found.
# No matching row for id 36893675 found.
# No matching row for id 13511010 found.
# No matching row for id 6667872 found.
# No matching row for id 42305636 found.
# No matching row for id 32478441 found.
# No matching row for id 340927 found.
# No matching row for id 23736968 found.
# No matching row for id 47670453 found.
# No matching row for id 23736968 found.
# No matching row for id 36893675 found.
# No matching row for id 9597841 found.
# No matching row for id 26036541 found.
# No matching row for id 23736968 found.
# No matching row for id 7009414 found.
# No matching row for id 9597841 found.
# No matching row for id 36893675 found.
# No matching row for id 46653940 found.
# No matching row for id 3509649 found.
# No matching row for id 42358235 found.
# No matching row for id 4060126 found.
# No matching row for id 39014312 found.
# No matching row for id 26036541 found.
# No matching row for id 32281941 found.
# No matching row for id 20895542 found.
# No matching row for id 36893675 found.
# No matching row for id 22410581 found.
# No matching row for id 7009414 found.
# No matching row for id 9597841 found.
# No matching row for id 22410581 found.
# No matching row for id 36893675 found.
# No matching row for id 20895542 found.
# No matching row for id 32281941 found.
# No matching row for id 47893551 found.
# No matching row for id 36575375 found.
# No matching row for id 42305636 found.
# No matching row for id 20895542 found.
# No matching row for id 3509649 found.
# No matching row for id 13511010 found.
# No matching row for id 7159975 found.
# No matching row for id 4060126 found.
# No matching row for id 41834571 found.
# No matching row for id 340927 found.
# No matching row for id 23736968 found.
# No matching row for id 3509649 found.
# No matching row for id 4254040 found.
# No matching row for id 27035875 found.
# No matching row for id 29406590 found.
# No matching row for id 4254040 found.
# No matching row for id 20895542 found.
# No matching row for id 36575375 found.
# No matching row for id 46508985 found.
# No matching row for id 29406590 found.
# No matching row for id 21885285 found.
# No matching row for id 13921110 found.
# No matching row for id 21885285 found.
# No matching row for id 22410581 found.
# No matching row for id 22371574 found.
# No matching row for id 46508985 found.
# No matching row for id 20895542 found.
# No matching row for id 22371574 found.
# No matching row for id 27035875 found.
# No matching row for id 41834571 found.
# No matching row for id 15522609 found.
# No matching row for id 9597841 found.
# No matching row for id 21885285 found.
# No matching row for id 20482878 found.
# No matching row for id 29406590 found.
# No matching row for id 2542615 found.
# No matching row for id 33441934 found.
# No matching row for id 4060126 found.
# No matching row for id 9597841 found.
# No matching row for id 22371574 found.
# No matching row for id 21885285 found.
# No matching row for id 6379698 found.
# No matching row for id 9597841 found.
# No matching row for id 32281941 found.
# No matching row for id 23736968 found.
# No matching row for id 6572839 found.
# No matching row for id 46653940 found.
# No matching row for id 29406590 found.
# No matching row for id 22410581 found.
# No matching row for id 23736968 found.
# No matching row for id 20895542 found.
# No matching row for id 6572839 found.
# No matching row for id 23736968 found.
# No matching row for id 32281941 found.
# No matching row for id 20895542 found.
# No matching row for id 23736968 found.
# No matching row for id 47893551 found.
# No matching row for id 42305636 found.
# No matching row for id 36575375 found.
# No matching row for id 32478441 found.
# No matching row for id 340927 found.
# No matching row for id 20895542 found.
# No matching row for id 36893675 found.
# No matching row for id 33441934 found.
# No matching row for id 22410581 found.
# No matching row for id 22410581 found.
# No matching row for id 36893675 found.
# No matching row for id 3509649 found.
# No matching row for id 22410581 found.
# No matching row for id 340927 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 32281941 found.
# No matching row for id 23736968 found.
# No matching row for id 4060126 found.
# No matching row for id 23736968 found.
# No matching row for id 23255883 found.
# No matching row for id 26036541 found.
# No matching row for id 27035875 found.
# No matching row for id 22371574 found.
# No matching row for id 36893675 found.
# No matching row for id 4060126 found.
# No matching row for id 9597841 found.
# No matching row for id 22410581 found.
# No matching row for id 13921110 found.
# No matching row for id 42358235 found.
# No matching row for id 42358235 found.
# No matching row for id 4060126 found.
# No matching row for id 9597841 found.
# No matching row for id 47893551 found.
# No matching row for id 42876958 found.
# No matching row for id 20895542 found.
# No matching row for id 23736968 found.
# No matching row for id 23736968 found.
# No matching row for id 36893675 found.
# No matching row for id 7009414 found.
# No matching row for id 39014312 found.
# No matching row for id 46508985 found.
# No matching row for id 33441934 found.
# No matching row for id 9597841 found.
# No matching row for id 9597841 found.
# No matching row for id 23736968 found.
# No matching row for id 29406590 found.
# No matching row for id 9597841 found.
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# We drop the NewPR column as we will no longer need it and can slow down the concatenation of the dataset with the terminal nodes' PR

# %%
PageRankPDF = PageRankPDF[['id','PR']]
PageRankPDF = pd.concat([PageRankPDF, TerminalNodes], ignore_index=True)
#display(PageRankPDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>PR</th></tr></thead><tbody><tr><td>15237</td><td>0.0</td></tr><tr><td>63125</td><td>0.0</td></tr><tr><td>34063244</td><td>0.0</td></tr><tr><td>390975</td><td>0.0</td></tr><tr><td>95840</td><td>0.0</td></tr><tr><td>3414021</td><td>0.0</td></tr><tr><td>17013058</td><td>0.0</td></tr><tr><td>47836950</td><td>0.0</td></tr><tr><td>313645</td><td>0.0</td></tr><tr><td>1982004</td><td>0.0</td></tr><tr><td>11930181</td><td>0.0</td></tr><tr><td>173547</td><td>0.0</td></tr><tr><td>869878</td><td>0.0</td></tr><tr><td>56615</td><td>0.0</td></tr><tr><td>149349</td><td>0.0</td></tr><tr><td>2830666</td><td>0.0</td></tr><tr><td>623636</td><td>0.0</td></tr><tr><td>24542030</td><td>0.0</td></tr><tr><td>3301134</td><td>0.0</td></tr><tr><td>11330258</td><td>0.0</td></tr><tr><td>122418</td><td>0.0</td></tr><tr><td>2497121</td><td>0.0</td></tr><tr><td>5478023</td><td>0.0</td></tr><tr><td>27274341</td><td>0.0</td></tr><tr><td>19127</td><td>0.0</td></tr><tr><td>68736</td><td>0.0</td></tr><tr><td>39024207</td><td>0.0</td></tr><tr><td>1393385</td><td>0.0</td></tr><tr><td>3434750</td><td>0.0</td></tr><tr><td>32706</td><td>0.0</td></tr><tr><td>9056994</td><td>0.0</td></tr><tr><td>25510448</td><td>0.0</td></tr><tr><td>528282</td><td>0.0</td></tr><tr><td>18660332</td><td>0.0</td></tr><tr><td>401880</td><td>0.0</td></tr><tr><td>8452507</td><td>0.0</td></tr><tr><td>1461079</td><td>0.0</td></tr><tr><td>3097027</td><td>0.0</td></tr><tr><td>17306237</td><td>0.0</td></tr><tr><td>313647</td><td>0.0</td></tr><tr><td>3343</td><td>0.0</td></tr><tr><td>31717</td><td>0.0</td></tr><tr><td>10079731</td><td>0.0</td></tr><tr><td>1303670</td><td>0
</td></tr><tr><td>63403</td><td>brian mulroney</td><td>0.0</td></tr><tr><td>41111875</td><td>1962–63 liga alef</td><td>0.0</td></tr><tr><td>41111875</td><td>1962–63 liga alef</td><td>0.0</td></tr><tr><td>81818</td><td>lagoon</td><td>0.0</td></tr><tr><td>13275</td><td>hungary</td><td>0.0</td></tr><tr><td>22309268</td><td>kwangmyŏngsŏng-1</td><td>0.0</td></tr><tr><td>446206</td><td>world poker tour</td><td>0.0</td></tr><tr><td>66633</td><td>moth</td><td>0.0</td></tr><tr><td>3929480</td><td>bobby au-yeung</td><td>0.0</td></tr><tr><td>7349754</td><td>neyriz county</td><td>0.0</td></tr><tr><td>20092504</td><td>kiki sheung</td><td>0.0</td></tr><tr><td>1298808</td><td>alan tam</td><td>0.0</td></tr><tr><td>10128</td><td>elizabeth i of england</td><td>0.0</td></tr><tr><td>5451380</td><td>lyoto machida</td><td>0.0</td></tr><tr><td>138005</td><td>kent, washingt ...

# %% [markdown]
# # Conclusions
# In order for the program to run as espected, the entire dataset of the wikipedia should be tested or an important number of ID's may find a mismatch
# ### Analysis of the dataset
# By making some displays we were able to get some first feelings on how the data was given. Noting that in the "text" column will be very relevant and that many other info was given.
#
# ### Preparing and parsing the text in each page
# With the Re module and a quite simple regular expresion we could parse the entire dataset and extract the info we needed, links, titles and id's.
#
# ### Preparing the dataframes
# Having applied a similar structure as in the Counting Words lab, we managed to count all the links in a specific id. Later on we created the Forward dataframe where we could find the id of a page, the outgoing links from the same page and the outgoing links from the links it had.
#
# An issue appeared when we got to terminal nodes, those with no links, we kept them appart for a while because their PR was going to be fixed.
# We then created the reverse links dataframe, which was the one to use in the calculation of the PageRank, with a similar structure as the previous one but now we had an id the links that pointed to that id and the links' outgoing counter. More than enough to calculate the PR for terminal and non-terminal nodes.
#
# ### Main loop & functions
# We tried hard trying to create the User Defined Functions but when trying to convert them to pandas dataframes was a complete mess so, we decided to do taylor it in our own way.
# We iterated by rows in the dataframe and because we had lists inside the links and outgoing columns with the same lenght we just called our function NewPageRank with those columns as parameters and the PR for the id of that row. Once in the function, it checked if there was a match between ids in the PageRank dataframe and if it was successful it took the PR and made the needed calculations, else it returned a warning error message and skiped to the next one. Once all the rows' PR was computed, we checked the variance condition with a very simple function, because we worked with pandas dataframes, we could make an operation on an entire column and so we did. The functin returned True or False if the variance condition was or not satisfied.
# On each iteration and before exiting the loop NewPR and PR are updated in order to have the latest computed value in PR in order to make the join with the Titles data.
#
# Before getting the final result, we appended the terminal nodes' PR computed long ago to the dataframe for it to contain all the possible information.
#
# Finally we made a join by the id column with the Title dataframe and reorder the columns to display it as suggested.
#
# ### Final statements
# It has been quite difficult to deal with the user defined function and with such a "large" dataset as we needed lots of instances of id, links and outgoing to propperly test our algorithms and performances. In fact, we could not test the performance as we would've liked to because we had some id's PR but their ingoing links weren't in the subset we could get. But at least we could test the mismatching-case in our algorithm.
#
# Having done and understood the previous homeworks and projects has indeed helped us figuring out a good algorithm and also to understand the errors and why certain things happen. Also we had to deal with the fact that the terminal nodes were not included in the ReverseLinks DF and so.
